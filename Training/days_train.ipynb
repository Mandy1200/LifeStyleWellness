# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("./data/data_days.csv")
df
# Out:
#        Student_ID  Age  Gender Lifestyle_Habits  Day  Sleep_Hours  \
# 0     S00001_D003   25  Female        Night Owl    3     6.694939
# 1     S00001_D007   25  Female        Night Owl    7     6.683871
# 2     S00001_D014   25  Female        Night Owl   14     6.587254
# 3     S00001_D021   25  Female        Night Owl   21     6.928135
# 4     S00001_D030   25  Female        Night Owl   30     7.036192
# ...           ...  ...     ...              ...  ...          ...
# 9850  S01095_D030   19  Female          Athlete   30     6.013780
# 9851  S01095_D045   19  Female          Athlete   45     6.524648
# 9852  S01095_D090   19  Female          Athlete   90     7.092886
# 9853  S01095_D182   19  Female          Athlete  182     6.977922
# 9854  S01095_D365   19  Female          Athlete  365     3.909430
#
#       Stress_Level  Study_Hours  Screen_Time_Post_10PM  \
# 0                8     4.611798               0.960507
# 1                5     6.488627               4.291530
# 2                6     6.147315               2.125834
# 3                5     5.035545               2.753121
# 4                8     4.391436               1.086402
# ...            ...          ...                    ...
# 9850             3     5.363681               4.013505
# 9851             8     5.769607               2.792254
# 9852             6     5.437663               2.439104
# 9853             7     4.777371               4.312982
# 9854             7     2.710269               2.932240
#
#       Physical_Activity_Minutes  Mood_Score  Sleep_Debt  \
# 0                           101    8.423197    0.561922
# 1                            55    6.334042    1.170893
# 2                            91    5.315147    2.775815
# 3                            54    5.302500    2.355538
# 4                            85    4.987899    2.291050
# ...                         ...         ...         ...
# 9850                         66    7.225866    1.886527
# 9851                         33    3.403293    2.988014
# 9852                         23    2.536204    2.637553
# 9853                         43    4.991345    2.910722
# 9854                         31    4.458326    2.651706
#
#       Stress_Per_Study_Hour  Burnout_Risk_Score  Overall_Wellbeing_Score  \
# 0                      1.73                0.14                     8.28
# 1                      0.77               -0.16                     6.49
# 2                      0.98                3.46                     1.86
# 3                      0.99                2.05                     3.25
# 4                      1.82                5.30                    -0.31
# ...                     ...                 ...                      ...
# 9850                   0.56               -2.34                     9.57
# 9851                   1.39                7.58                    -4.18
# 9852                   1.10                6.10                    -3.56
# 9853                   1.47                4.92                     0.07
# 9854                   2.58                5.19                    -0.73
#
#       Sleep_Quality_Score  Mental_Fatigue_Score
# 0                    6.12                  0.86
# 1                    6.34                  1.75
# 2                    6.07                  4.07
# 3                    6.57                  3.37
# 4                    6.51                  5.16
# ...                   ...                   ...
# 9850                 5.68                  0.22
# 9851                 6.31                  7.09
# 9852                 6.87                  6.78
# 9853                 6.67                  4.96
# 9854                 3.96                  5.37
#
# [9855 rows x 17 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Encode Gender
# df["Gender"] = LabelEncoder().fit_transform(df["Gender"])  # Female=0, Male=1, Other=2

# Encode Lifestyle_Habits (optional)
df["Lifestyle_Score"] = LabelEncoder().fit_transform(df["Lifestyle_Habits"])

features = [
    "Age",  
    "Sleep_Hours", 
    "Study_Hours",
    "Screen_Time_Post_10PM", 
    "Physical_Activity_Minutes", 
    "Mood_Score",
    "Sleep_Debt", 
    "Day", 
    "Lifestyle_Score"
]

target = [
    "Burnout_Risk_Score", 
    "Stress_Level", 
    "Stress_Per_Study_Hour",
    "Overall_Wellbeing_Score", 
    "Sleep_Quality_Score", 
    "Mental_Fatigue_Score"
]

# %%
X = df[features]
y = df[target]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor

model = MultiOutputRegressor(RandomForestRegressor(n_estimators=200, random_state=42))
model.fit(X, y)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(n_estimators=200,
#                                                      random_state=42))

# %%
y_pred = model.predict(X_test)
print("R² Score:", r2_score(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# R² Score: 0.9563853111967534
# RMSE: 0.3003955886727053

# %%
import pandas as pd

# Base user input
base_user = {
    "Age": 22,
    "Sleep_Hours": 6.5,
    "Study_Hours": 8.0,  
    "Screen_Time_Post_10PM": 5.2,
    "Physical_Activity_Minutes": 30,
    "Mood_Score": 5.8,
    "Sleep_Debt": 1.4 , 
    "Day": 14 , # Will be overwritten by loop
    "Lifestyle_Score":3

    
}

# Days to forecast
future_days = [3, 7, 14, 21, 30, 45, 90, 182, 365]

# Create forecast DataFrame
forecast_df = pd.DataFrame([
    {**base_user, "Day": d} for d in future_days
])

# Predict multiple scores
predicted_outputs = model.predict(forecast_df)

# Define target column names (same order used during training)
output_labels = [
    "Burnout_Risk_Score", 
    "Stress_Level", 
    "Stress_Per_Study_Hour",
    "Overall_Wellbeing_Score", 
    "Sleep_Quality_Score", 
    "Mental_Fatigue_Score"
]

# Show results
for day, scores in zip(future_days, predicted_outputs):
    print(f"\n📅 Day {day}")
    for label, score in zip(output_labels, scores):
        print(f"   🔹 {label}: {round(score, 2)}")
# Out:
# 📅 Day 3
#    🔹 Burnout_Risk_Score: 0.68
#    🔹 Stress_Level: 4.8
#    🔹 Stress_Per_Study_Hour: 0.73
#    🔹 Overall_Wellbeing_Score: 4.41
#    🔹 Sleep_Quality_Score: 6.29
#    🔹 Mental_Fatigue_Score: 2.79
#
# 📅 Day 7
#    🔹 Burnout_Risk_Score: 1.8
#    🔹 Stress_Level: 5.92
#    🔹 Stress_Per_Study_Hour: 0.73
#    🔹 Overall_Wellbeing_Score: 3.76
#    🔹 Sleep_Quality_Score: 6.29
#    🔹 Mental_Fatigue_Score: 3.17
#
# 📅 Day 14
#    🔹 Burnout_Risk_Score: 2.22
#    🔹 Stress_Level: 6.54
#    🔹 Stress_Per_Study_Hour: 0.78
#    🔹 Overall_Wellbeing_Score: 3.52
#    🔹 Sleep_Quality_Score: 6.29
#    🔹 Mental_Fatigue_Score: 3.28
#
# 📅 Day 21
#    🔹 Burnout_Risk_Score: 2.31
#    🔹 Stress_Level: 6.55
#    🔹 Stress_Per_Study_Hour: 0.76
#    🔹 Overall_Wellbeing_Score: 3.44
#    🔹 Sleep_Quality_Score: 6.29
#    🔹 Mental_Fatigue_Score: 3.37
#
# 📅 Day 30
#    🔹 Burnout_Risk_Score: 2.32
#    🔹 Stress_Level: 6.76
#    🔹 Stress_Per_Study_Hour: 0.78
#    🔹 Overall_Wellbeing_Score: 3.24
#    🔹 Sleep_Quality_Score: 6.29
#    🔹 Mental_Fatigue_Score: 3.41
#
# 📅 Day 45
#    🔹 Burnout_Risk_Score: 2.22
#    🔹 Stress_Level: 6.02
#    🔹 Stress_Per_Study_Hour: 0.78
#    🔹 Overall_Wellbeing_Score: 3.41
#    🔹 Sleep_Quality_Score: 6.29
#    🔹 Mental_Fatigue_Score: 3.36
#
# 📅 Day 90
#    🔹 Burnout_Risk_Score: 2.35
#    🔹 Stress_Level: 6.19
#    🔹 Stress_Per_Study_Hour: 0.79
#    🔹 Overall_Wellbeing_Score: 3.4
#    🔹 Sleep_Quality_Score: 6.29
#    🔹 Mental_Fatigue_Score: 3.35
#
# 📅 Day 182
#    🔹 Burnout_Risk_Score: 2.38
#    🔹 Stress_Level: 6.78
#    🔹 Stress_Per_Study_Hour: 0.72
#    🔹 Overall_Wellbeing_Score: 3.36
#    🔹 Sleep_Quality_Score: 6.3
#    🔹 Mental_Fatigue_Score: 3.36
#
# 📅 Day 365
#    🔹 Burnout_Risk_Score: 2.41
#    🔹 Stress_Level: 6.88
#    🔹 Stress_Per_Study_Hour: 0.71
#    🔹 Overall_Wellbeing_Score: 3.36
#    🔹 Sleep_Quality_Score: 6.3
#    🔹 Mental_Fatigue_Score: 3.36

# %%
# Assume `predicted_outputs` is a NumPy array of shape (9 days, 6 scores)
target_names = [
    "Burnout Risk",
    "Stress Level",
    "Stress/Study Hr",
    "Wellbeing",
    "Sleep Quality",
    "Mental Fatigue"
]

colors = ['tomato', 'royalblue', 'green', 'orange', 'purple', 'brown']

plt.figure(figsize=(12, 6))

for i in range(predicted_outputs.shape[1]):
    plt.plot(future_days, predicted_outputs[:, i], marker='o', label=target_names[i], color=colors[i])

plt.title("📉 Forecasted Lifestyle Indicators Over Time", fontsize=16, fontweight='bold')
plt.xlabel("Day", fontsize=12)
plt.ylabel("Score", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(future_days)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11312\1634593270.py:24: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
with open("days_trainer.pkl", "wb") as f:
    pickle.dump(model, f)
